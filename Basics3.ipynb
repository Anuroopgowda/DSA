# %%
b=5
try:
    ans=5/1
    print(ans)
    b=5
except:
    print("exception")
print(b)
# Out:
# 5.0
# 5

# %%
def add1(a,b):
    return a+b
def perform(func,a,b):
    return func(a,b)
print(perform(add1,2,5))
# Out:
# 7

# %%
lst=[1,2,3]
tup=tuple(lst)
tup
# Out:
# (1, 2, 3)

# %%
str1="anuroop gowda"
lst=[]
lst=str1.split()
lst
# Out:
# ['anuroop', 'gowda']

# %%
class animal:
    def speek(self):
        return "animal"
    
class dog(animal):
    def barke(self):
        return "dog barke"
    
obj=animal()
obj.speek()
obj1=dog()
obj1.barke()
# Out:
# 'dog barke'

# %%
class animal1:
    def speek(self):
        return "animal"
class animal2(animal1):
    def speek1(self):
        return "animal speek"
class dog(animal1,animal2):
    def barke(self):
        return "dog barke"
obj=dog()
obj.speek()
obj.speek1()
# Out:
# 'animal speek'

# %%
class Animal:
    def add(self,a,b):
        return a+b
    
class Dog:
    def cal(self,a,b):
        num=super().add(a,b)
        return num
    
obj=Dog()
print(obj.cal(2,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17128\466431602.py in <module>
#       9
#      10 obj=Dog()
# ---> 11 print(obj.cal(2,3))
#      12
#
# ~\AppData\Local\Temp\ipykernel_17128\466431602.py in cal(self, a, b)
#       5 class Dog:
#       6     def cal(self,a,b):
# ----> 7         num=super().add(a,b)
#       8         return num
#       9
#
# AttributeError: 'super' object has no attribute 'add'

# %%
class Animal:
    def add(self, a, b):
        return a + b
    
class Dog(Animal):
    def cal(self):
        num = super().add(2, 3)
        return num

obj = Dog()
print(obj.cal())
# Out:
# 5

# %%
from abc import ABC, abstractmethod

# Abstract class
class Shape(ABC):
    
    @abstractmethod
    def area(self):
        pass
    
    @abstractmethod
    def perimeter(self):
        pass

# Concrete class
class Rectangle(Shape):
    
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.width
    
    def perimeter(self):
        return 2 * (self.length + self.width)

# Concrete class
class Circle(Shape):
    
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14 * self.radius * self.radius
    
    def perimeter(self):
        return 2 * 3.14 * self.radius

# Create objects
rect = Rectangle(10, 5)
circ = Circle(7)

print("Rectangle Area:", rect.area())
print("Rectangle Perimeter:", rect.perimeter())
print("Circle Area:", circ.area())
print("Circle Perimeter:", circ.perimeter())
# Out:
# Rectangle Area: 50
# Rectangle Perimeter: 30
# Circle Area: 153.86
# Circle Perimeter: 43.96

# %%
def greetdecorator(func):
    def wrapper():
        print("hello")
        func()
        print("goodbye")
    return wrapper
@greetdecorator
def greet():
    print("hi anuroop")
    
greet()
# Out:
# hello
# hi anuroop
# goodbye

# %%
# A simple decorator function
def greet_decorator(func):
    def wrapper():
        print("Hello!")  # Code to run before the original function
        func()           # Original function
        print("Goodbye!") # Code to run after the original function
    return wrapper

# Applying the decorator to a function
@greet_decorator
def greet():
    print("Welcome to Python!")

# Calling the decorated function
greet()
# Out:
# Hello!
# Welcome to Python!
# Goodbye!

# %%
def func():
    yield 1
    yield 2

for value in func():
    print(value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33372\389333994.py in <module>
#       3     yield 2
#       4
# ----> 5 for value in fun():
#       6     print(value)
#
# NameError: name 'fun' is not defined

# %%
chara="a"
step=2
str1=''
if(chara.islower()):
    str1+=chr((ord(chara)+step-97)%26+97)
print(str1)
# Out:
# c

# %%
num=1634
str1=str(num)
n=len(str1)
total=0

for i in str1:
    total+=int(i)**n

if total ==num:
    print("yes")
else:
    print('no')
# Out:
# yes

# %%
import math
def lcm(a,b):
    return abs(a*b)//math.gcd(a,b)

a,b=4,6
print(lcm(a,b))
# Out:
# 12

# %%
s='anuroop'
s1='anuroop'
if sorted(s)==sorted(s1):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
def gcd(a,b):
    while b:
        a,b=b,b%a
    return a

a,b=3,4
print(gcd(a,b))

# %%
arr=[1,1,2,3,4,3,3,5]
su=6
arr.sort()
print(arr)
left=0
right=len(arr)-1
count=0
while left<right:
    suu=arr[left]+arr[right]
    if suu==su:
        count+=1
        print(arr[left],arr[right])
        left+=1
        right-=1
    elif suu<su:
        left+=1
    else:
        right-=1
print(count)
# Out:
# [1, 1, 2, 3, 3, 3, 4, 5]
# 1 5
# 2 4
# 3 3
# 3

# %%
def deco(anuroop):
    print("anu")
    def wrapper():
        print("wrapper")
        anuroop()
        print("wrapper2")
    return wrapper

@deco
def say():
    print("say")
    
        
say()
# Out:
# anu
# wrapper
# say
# wrapper2

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
    def insert(self,data):
        newnode=Node(data)
        if self.head==None:
            self.head=newnode
            return
        cur=self.head
        while cur.next!=None:
            cur=cur.next
        cur.next=newnode
        
    def reverse(self):
        prev=None
        cur=self.head
        while cur:
            temp=cur.next
            cur.next=prev
            prev=cur
            cur=temp
        self.head=prev
            
        
    def display(self):
        cur=self.head
        while cur:
            print(cur.data)
            cur=cur.next
            
        
        
ll=LinkedList()       
lst=[1,2,3]
for i in lst:
    ll.insert(i)
ll.reverse()
ll.display()
# Out:
# 3
# 2
# 1

# %%
with open('bashu','r') as f:
    print(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12000\1041191002.py in <module>
# ----> 1 with open('bashu','r') as f:
#       2     print(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bashu'
