# %%
s = "anagram", t = "nagaram"
dict1={}
for i in s:
    if i not in dict1:
        dict1[i]=1
    else:
        dict1[i]+=1
for j in t:
    if j not in dict1:
         return False

    elif dict1[i]-1>0:
        dict1[i]-=1
        if dict1[j]==0:
            print(1)
            dict1.pop(j) #use to remove key in dictionary
        else:
             return False
if len(dict1)!=0:
    return False
return True
# Out:
#   File "C:\Users\anuro\AppData\Local\Temp\ipykernel_27100\342216899.py", line 1
#     s = "anagram", t = "nagaram"
#         ^
# SyntaxError: cannot assign to literal
